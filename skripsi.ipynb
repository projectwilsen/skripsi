# %%
# !pip install --upgrade --quiet  langchain-core langchain-community langchain-openai langchain-groq langchain neo4j python-dotenv
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from langchain_community.graphs import Neo4jGraph
from langchain_groq import ChatGroq
from langchain.chains import GraphCypherQAChain
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate, PromptTemplate
import os
from dotenv import load_dotenv
load_dotenv()

groq_api = os.getenv("GROQ_API_KEY")

# Neo4j 
neo4j_url = os.getenv("NEO4J_CONNECTION_URL")
neo4j_user = os.getenv("NEO4J_USER")
neo4j_password = os.getenv("NEO4J_PASSWORD")

# https://api.python.langchain.com/en/latest/graphs/langchain_community.graphs.neo4j_graph.Neo4jGraph.html
graph = Neo4jGraph(neo4j_url,neo4j_user,neo4j_password)

# %% [markdown]
# # Prepare Data

# %%
df
# Out:
#          id nomor_registrasi   types  \
# 0      7471      TR143677741     NaN
# 1      2022      TR153689541     NaN
# 2      2021      TR153689541     NaN
# 3       448      TR143381131  kapsul
# 4      2269  GKL2004529817B1  tablet
# ...     ...              ...     ...
# 10053  4900  DKL9513011046A1   tetes
# 10054  7492      TI134347671  kapsul
# 10055  9441  GKL1405049017A1  tablet
# 10056  7491      TI134347671  kapsul
# 10057  6397  DKL9217607917A1  tablet
#
#                                       prepro_indications  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 10053  gangguan inflamasi ocular diindikasikan kortik...
# 10054  membantu memelihara kesehatan , membantu mence...
# 10055  eyesight kitty kawaii mini olivia light brown ...
# 10056  membantu mencegah timbulnya enzim merusak jari...
# 10057  masalah pendinginan jangka pendek cepat olah r...
#
#                                            cleaned_names
# 0                                                teenmax
# 1                                                mixsaga
# 2                                                mixsaga
# 3                                               pasopati
# 4                                             etoricoxib
# ...                                                  ...
# 10053                          ximex optixitrol eye drop
# 10054                  natures health grape seed extract
# 10055  eyesight kitty kawaii mini olivia light brown ...
# 10056                  natures health grape seed extract
# 10057                                              sitro
#
# [10058 rows x 5 columns]

# %%
bpom
# Out:
#        Unnamed: 0 nomor_registrasi            produk  \
# 0               0  DTL2341200729A1              Obat
# 1               1  DBL1721207537A1              Obat
# 2               2  DKI0585600517A1              Obat
# 3               3  DKL1035307649A2              Obat
# 4               4  DKL0635305209A1              Obat
# ...           ...              ...               ...
# 40717       40717      TI134347481  Obat Tradisional
# 40718       40718      TR152587911  Obat Tradisional
# 40719       40719      TR033429701  Obat Tradisional
# 40720       40720      TR182310241  Obat Tradisional
# 40721       40721      TI114345391  Obat Tradisional
#
#                      nama_produk  \
# 0                        NIZORAL
# 1                    DULCOLACTOL
# 2                          ARAVA
# 3                        RONAZOL
# 4                   CYTROPIL 800
# ...                          ...
# 40717  BU SHEN YI SHOU JIAO NANG
# 40718                    HEBATOP
# 40719           MAJAKANI PERAPAT
# 40720                     OLIVIN
# 40721   NATURALLE GARLIC 3000 MG
#
#                                           bentuk_sediaan  \
# 0                                             KRIM 20 MG
# 1                                                  SIRUP
# 2                             TABLET SALUT SELAPUT 20 MG
# 3                                           INFUS 500 MG
# 4                            KAPLET SALUT SELAPUT 800 MG
# ...                                                  ...
# 40717                       Botol @ 60 kapsul @ 0.3 gram
# 40718                 Dus, Amplop @ 5 Blister @ 2 Kaplet
# 40719  Dus, 12 bungkus @ 6 pil @ 200 mg\nDus, 3 bungk...
# 40720                         Dus, 3 blister @ 10 kapsul
# 40721                       Dus, botol @100 kapsul lunak
#
#                                                komposisi  \
# 0                                         - KETOCONAZOLE
# 1                                - LACTULOSE CONCENTRATE
# 2                                          - LEFLUNOMIDE
# 3                                        - METRONIDAZOLE
# 4                                            - PIRACETAM
# ...                                                  ...
# 40717                          - ganoderma fructificatio
# 40718                          - Ekstrak Eurycomae Radix
# 40719                              - Areca Catechu Semen
# 40720  - Olea Europaea setara dengan hydroxytirosol 5 mg
# 40721                         - Oleum Alii Sativi bulbus
#
#                                                    klaim
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40717                               memelihara kesehatan
# 40718                   Membantu memelihara stamina pria
# 40719  Membantu mengurangi lendir yang berlebihan pad...
# 40720                      membantu memelihara kesehatan
# 40721                      Membantu memelihara kesehatan
#
# [40722 rows x 7 columns]

# %%
df = pd.read_csv('data_obat_fix_ordered (2).csv', sep = ',')
df = df[['id','nomor_registrasi','types','prepro_indications','cleaned_names']]
bpom = pd.read_csv('bpom_full.csv')
merge= pd.merge(df, bpom, on='nomor_registrasi', how='left')[['id','nomor_registrasi','types','prepro_indications','cleaned_names','nama_produk','komposisi','klaim']]
merge['komposisi'] = merge['komposisi'].astype(str).apply(lambda x: x.lower().replace('- ', '').replace('.', '|'))
merge['nama'] = merge['nama_produk'].astype(str).apply(lambda x: x.lower())
merge['prepro_indications'] = merge['prepro_indications'].fillna(merge['klaim'])
merge = merge[['id','nomor_registrasi','nama','types','komposisi','prepro_indications']]
merge.drop_duplicates(subset=['nomor_registrasi', 'nama'], inplace = True)
merge = merge.sort_values(by = 'id').reset_index(drop=True)
merge
# Out:
#          id nomor_registrasi                nama   types  \
# 0         0  GKL1433531717A1  sildenafil citrate  tablet
# 1         5  DKI1690401417A1              viagra  tablet
# 2         7  DKL1333528917A1             ericfil  tablet
# 3         9  DKI1973401817C1              cialis  tablet
# 4        12  DKL2233554519A1          ericfil 50     odf
# ...     ...              ...                 ...     ...
# 4749  10053      TR132474581   sinargi astramuno     pil
# 4750  10054      TR213603191           probiomag    madu
# 4751  10055      TR183613971      madu gurah fit    madu
# 4752  10056      TR183622691       madu nurutenz    madu
# 4753  10057      TR203641411       madu vitomata    madu
#
#                                               komposisi  \
# 0                                    sildenafil citrate
# 1                                    sildenafil citrate
# 2                                    sildenafil citrate
# 3                                             tadalafil
# 4                                    sildenafil citrate
# ...                                                 ...
# 4749                      astragalus membranaceus radix
# 4750                  ekstrak cinamommum burmani cortex
# 4751                   abrus precatorius folium extract
# 4752                     apium graveolens herba ekstrak
# 4753  bilberry (vaccinum myrtillus) fruit extract po...
#
#                                      prepro_indications
# 0                   terapi disfungsi ereksi pria dewasa
# 1                   terapi disfungsi ereksi pria dewasa
# 2      ericfil diindikasikan mengobati disfungsi ereksi
# 3     pengobatan ketidakmampuan mencapai mempertahan...
# 4                   terapi disfungsi ereksi pria dewasa
# ...                                                 ...
# 4749                      membantu memelihara kesehatan
# 4750  meringankan gangguan pencernaan , perut mual k...
# 4751                           membantu meredakan batuk
# 4752                      meringankan gejala hipertensi
# 4753                 membantu memelihara kesehatan mata
#
# [4754 rows x 6 columns]

# %%
model = ChatGroq(model="llama3-70b-8192",groq_api_key = groq_api)

def process_indikasi(text):
  template = """
      Extract the types of diseases that can be cured from a given text.
      If more than one, separate them with '|', do not use any other symbols.
      Do not add any explanations, reasoning or preambles, if none exist then return 'None'.
      Your output should be in Bahasa Indonesia

      Example:

      text = "membantu meringankan tekanan darah ringan"
      helpful answer = "tekanan darah ringan"

      text = "pengobatan ketidakmampuan mencapai mempertahankan ereksi berhubungan seksual disfungsi ereksi pria dewasa , mengobati penderita pembesaran prostat jinak bph hipertensi pulmonal tekanan pembuluh darah arteri paru - paru"
      helpful answer = "disfungsi ereksi|pembesaran prostat jinak|hipertensi|tekanan pembuluh darah arteri paru-paru"

      text: {text}
      helpful answer:
      """

  prompt = ChatPromptTemplate.from_template(template = template)
  output_parser = StrOutputParser()

  chain = prompt | model | output_parser

  result = chain.invoke({"text": text})
  print(result)
  return result

# %%
result = process_indikasi("mengurangi kejadian aterosklerosis infark miokard , stroke kematian vaskular pasien aterosklerosis ditandai stroke , infark miokard penyakit arteri")
# Out:
# disfungsi ereksi|pembesaran prostat|hipertensi|infark miokard|stroke|penyakit arteri

# %%
merge
# Out:
#          id nomor_registrasi                nama   types  \
# 0         0  GKL1433531717A1  sildenafil citrate  tablet
# 1         5  DKI1690401417A1              viagra  tablet
# 2         7  DKL1333528917A1             ericfil  tablet
# 3         9  DKI1973401817C1              cialis  tablet
# 4        12  DKL2233554519A1          ericfil 50     odf
# ...     ...              ...                 ...     ...
# 4749  10053      TR132474581   sinargi astramuno     pil
# 4750  10054      TR213603191           probiomag    madu
# 4751  10055      TR183613971      madu gurah fit    madu
# 4752  10056      TR183622691       madu nurutenz    madu
# 4753  10057      TR203641411       madu vitomata    madu
#
#                                               komposisi  \
# 0                                    sildenafil citrate
# 1                                    sildenafil citrate
# 2                                    sildenafil citrate
# 3                                             tadalafil
# 4                                    sildenafil citrate
# ...                                                 ...
# 4749                      astragalus membranaceus radix
# 4750                  ekstrak cinamommum burmani cortex
# 4751                   abrus precatorius folium extract
# 4752                     apium graveolens herba ekstrak
# 4753  bilberry (vaccinum myrtillus) fruit extract po...
#
#                                      prepro_indications
# 0                   terapi disfungsi ereksi pria dewasa
# 1                   terapi disfungsi ereksi pria dewasa
# 2      ericfil diindikasikan mengobati disfungsi ereksi
# 3     pengobatan ketidakmampuan mencapai mempertahan...
# 4                   terapi disfungsi ereksi pria dewasa
# ...                                                 ...
# 4749                      membantu memelihara kesehatan
# 4750  meringankan gangguan pencernaan , perut mual k...
# 4751                           membantu meredakan batuk
# 4752                      meringankan gejala hipertensi
# 4753                 membantu memelihara kesehatan mata
#
# [4754 rows x 6 columns]

# %%
sample = merge.sample(frac=10, replace = True).sample(n=100)
sample
# Out:
#         id nomor_registrasi                       nama   types  \
# 1621  3514  DKL1007810604A1                    hufadon  kaplet
# 4175  8759  DKL0804520010A1                    norizec  tablet
# 4356  9097  DKI0367501817C1                     diovan  tablet
# 2165  4681  DKL1203813646A1                 lentikular   tetes
# 287    926  DKL0804130337A1  comtusi (rasa strawberry)   sirup
# ...    ...              ...                        ...     ...
# 3324  6728  DKL0304421302B1                      oscal  kapsul
# 3090  6354  DKL0609215704A1                    rexavin  kaplet
# 1683  3612  DKL1733537682A1                     monell  tablet
# 2463  5356  DKL0434601629A1                     afucid    krim
# 2639  5674  GKL0208505538A1     cefadroxil monohydrate   sirup
#
#                      komposisi  \
# 1621               domperidone
# 4175               glimepiride
# 4356                 valsartan
# 2165                pirenoxine
# 287   oxomemazine| guaifenesin
# ...                        ...
# 3324                calcitriol
# 3090              griseofulvin
# 1683               domperidone
# 2463              fusidic acid
# 2639    cefadroxil monohydrate
#
#                                      prepro_indications
# 1621  terapi mual muntah disebabkan levodopa bromokr...
# 4175  diabetes melitus tipe 2 non - insulin - depend...
# 4356  hipertensi , gagal jantung , pasca infark miokard
# 2165                 membantu mengatasi kekeringan mata
# 287   untuk meringankan gejala batuk alergi , batuk ...
# ...                                                 ...
# 3324  osteoporosis pasca menopause  osteodistrofi re...
# 3090                                                NaN
# 1683  mual muntah akut , dispepsia gangguan pencerna...
# 2463  impetigo kontagiosum , folikulitis superfisial...
# 2639  mengatasi infeksi saluran pernafasan , saluran...
#
# [100 rows x 6 columns]

# %%
sample['indikasi'] = sample['prepro_indications'].map(process_indikasi)
# Out:
# mual muntah|kanker|dispepsia fungsional
# diabetes melitus tipe 2|non-insulin-dependent type ii diabetes melitus|niddm
# hipertensi|gagal jantung|infark miokard
# kekeringan mata
# batuk alergi|batuk berdahak
# asma bronkial|bronkritis kronik|emfisema
# alergi saluran pernapasan|alergi kulit|mata
# None
# None
# batuk|demam|sakit kepala|hiding bersin-bersin
# alergi rinitis nasal|rinitis intermiten persisten|pruritus|urtikaria khronik idiopathik
# Here is the answer:
#
# infeksi sal cerna|infeksi sal nafas|infeksi bakteri
# hipertensi|penyakit arteri koroner
# kandidiasis mukokutan khronis|infeksi jamur sistemik
# hipertensi|gagal jantung kronik
# batuk pilek
# batuk
# disfungsi ereksi|pembesaran prostat jinak|hipertensi|tekanan pembuluh darah arteri paru-paru
# None
# sakir kepala|sakit gigi|dismenore primer|nyeri trauma|nyeri otot|nyeri operasi
# infeksi saluran kemih|otitis medium|radang rongga gendang telinga|faringitis|tonsilitis|bronkhitis akut|bronkhitis kronis
# sakit kepala
# dehidrasi ringan|diare|muntah
# hipsterplasia prostat jinak bph|hipertensi
# None
# rematik|artritis rematoid|ankylosing spondylitis|osteoartritis|spondilartritis|sindroma nyeri kolumna vertebralis|rematik non-artikular|serangan akut gout|nyeri pascabedah
# None
# hemoroid|wasir internal|wasir eksternal|luka anus|luka perineum|prolaps anus|fistula|peradangan rektum|pruritus anus
# None
# nyeri ringan sakit kepala|sakit gigi|sakit otot|demam
# hipertensi|iskemia miokard|obstruksi angina|angina prinzmetal|vasospasme|vasokonstriksi
# konstipasi
# hipertensi|iskemia miokard|obstruksi angina|angina prinzmetal|vasospasme|vasokonstriksi
# penyumbatan saluran nafas|asma
# sakit perut|perut kembung|gatal-gatal
# None
# diabetes melitus tipe 2|non-insulin-dependent type ii diabetes melitus|niddm
# infeksi saluran pernafasan|infeksi saluran kemih|infeksi kulit jaringan lunak
# infeksi pernafasan|infeksi saluran cerna|infeksi ricketsia|limfogranuloma|meningococcus|gonoccus|infeksi t pallidium
# biang keringat|gatal-gatal kulit|bau badan
# tuberkulosis|tuberkulosis meningitis
# artritis kronik|oa|spondilitis ankilosa
# batuk non produktif
# kencing manis
# migren|gangguan vaskular vestibular|periferal serebral
# None
# None
# ulkus tukak lambung usus halus|reflux esofagitis|sindrom zollinger - ellison
# cacingan
# gangguan saluran pernapasan akut kronik
# angina pektoris|hipertensi ringan
# gusi bengkak|sakit tenggorokan|sariawan|bau mulut
# infeksi saluran pernafasan|infeksi saluran kemih kelamin|infeksi kulit jaringan lunak
# infeksi bakteri|jamur|fungi|rongga mulut tenggorokan
# perut kembung
# Here is the answer:
#
# tenggorokan|peradangan rongga mulut tenggorokan|gingivitis|faringitis|periodontitis|laringitis|angina|infeksi selaput lendir mulut stomatitis
# batuk
# demam|nyeri sendi|nyeri telinga|sakit kepala|reumatik|flu infeksi
# rematoid atritis akut kronis|spondilitis ankilosa|dismenore|nyeri tulang|nyeri gigi ringan
# infeksi saluran kemih|otitis medium|radang rongga gendang telinga|faringitis|tonsilitis|bronkhitis akut|bronkhitis kronis
# diabetes
# sakıt kepala|perut kembung|masuk angin|mabuk perjalanan|gejala flu|pegal-pegal gatal akibat gigitan serangga
# glaukoma sudut terbuka|glaukoma sekunder|glaukoma sudut tertutup
# open angle glaucoma|hipertensi okular
# flu|demam|sakit kepala|hidung tersumbat|batuk
# demam|sakit kepala|sakit gigi
# batuk produktif
# hipertensi
# flu|demam|sakit kepala|hidung tersumbat|bersin-bersin
# None
# mual muntah
# infertilitas wanita|oligomenore|amenore sekunder|oligospermia
# mual|muntah
# wasir
# konstipasi akut|pengosongan usus
# ulkus peptik|gastritis
# None
# None
# sakit kepala|sakit gigi|demam
# gagal jantung|gangguan fungsi sistolik ventrikel kiri|hipertensi
# Here is the answer:
#
# sakit kepala|sakit gigi|nyeri haid primer|nyeri trauma|nyeri otot|nyeri paska operasi
# batuk berdahak
# nyeri paroxismal lambung usus halus|nyeri spastik saluran empedu|saluran kemih organ genital wanita
# infeksi saluran nafas
# diabetes melitus tipe 2|non-insulin-dependent type ii diabetes melitus|niddm
# Here is the answer:
#
# nyeri sakit kepala|sakit gigi|demam|flu
# hipertensi|gagal jantung kongestif|infark miokard
# iritasi mata
# akne vulgaris
# hipertensi|gagal jantung|infark miokard
# rinitis menahun|rinitis alergi seasonal|konjungtivitis|pruritus|urtikaria idiopati kronis
# infeksi saluran kemih|otitis medium|radang rongga gendang telinga|faringitis|tonsilitis|bronkhitis akut|bronkhitis kronis
# None
# gangguan sulit tidur
# infeksi saluran pernafasan|infeksi kulit jaringan lunak|infeksi saluran kemih kelamin|infeksi osteomielitis radang sumsum tulang|septikemia keracunan darah|peritonitis radang selaput perut|infeksi operasi
# osteoporosis|osteodistrofi renal|gangguan ginjal kronik|hipoparatiroidisme|pseudohipoparatiroidisme|rickets
# None
# mual muntah akut|mual muntah anak akibat kemoterapi radioterapi|dispepsia gangguan pencernaan
# impetigo kontagiosum|folikulitis superfisial|furunkulosis|sikosis barbae|hidradenitis aksilaris|abs|paronikia|eritrasma
# infeksi saluran pernafasan|infeksi saluran kemih|infeksi kulit|infeksi jaringan lunak

# %%
sample.to_csv('sample_skripsi.csv', index = False)

# %%
sample = pd.read_csv('sample_skripsi.csv')
sample
# Out:
#       id nomor_registrasi                       nama    tipe  \
# 0   3514  DKL1007810604A1                    hufadon  kaplet
# 1   8759  DKL0804520010A1                    norizec  tablet
# 2   9097  DKI0367501817C1                     diovan  tablet
# 3   4681  DKL1203813646A1                 lentikular   tetes
# 4    926  DKL0804130337A1  comtusi (rasa strawberry)   sirup
# ..   ...              ...                        ...     ...
# 95  6728  DKL0304421302B1                      oscal  kapsul
# 96  6354  DKL0609215704A1                    rexavin  kaplet
# 97  3612  DKL1733537682A1                     monell  tablet
# 98  5356  DKL0434601629A1                     afucid    krim
# 99  5674  GKL0208505538A1     cefadroxil monohydrate   sirup
#
#                    komposisi  \
# 0                domperidone
# 1                glimepiride
# 2                  valsartan
# 3                 pirenoxine
# 4   oxomemazine| guaifenesin
# ..                       ...
# 95                calcitriol
# 96              griseofulvin
# 97               domperidone
# 98              fusidic acid
# 99    cefadroxil monohydrate
#
#                                              indikasi
# 0             mual muntah|kanker|dispepsia fungsional
# 1   diabetes melitus tipe 2|non-insulin-dependent ...
# 2             hipertensi|gagal jantung|infark miokard
# 3                                     kekeringan mata
# 4                         batuk alergi|batuk berdahak
# ..                                                ...
# 95  osteoporosis|osteodistrofi renal|gangguan ginj...
# 96                                                NaN
# 97  mual muntah akut|mual muntah anak akibat kemot...
# 98  impetigo kontagiosum|folikulitis superfisial|f...
# 99  infeksi saluran pernafasan|infeksi saluran kem...
#
# [100 rows x 6 columns]

# %%
data = pd.read_csv('data_obat_fix_ordered (2).csv')
# print(data[data['nomor_registrasi'] == 'DKL1007810604A1']['prepro_indications'].to_list()[0])
data
# Out:
#          id nomor_registrasi            produk  \
# 0      7471      TR143677741  Obat Tradisional
# 1      2022      TR153689541  Obat Tradisional
# 2      2021      TR153689541  Obat Tradisional
# 3       448      TR143381131  Obat Tradisional
# 4      2269  GKL2004529817B1              Obat
# ...     ...              ...               ...
# 10053  4900  DKL9513011046A1              Obat
# 10054  7492      TI134347671  Obat Tradisional
# 10055  9441  GKL1405049017A1              Obat
# 10056  7491      TI134347671  Obat Tradisional
# 10057  6397  DKL9217607917A1              Obat
#
#                                                     name  \
# 0                                         Teenmax 350 ml
# 1                                          Mixsaga 10 ml
# 2                                          Mixsaga 10 ml
# 3                                     Pasopati 15 Kapsul
# 4                            Etoricoxib 120 mg 10 Tablet
# ...                                                  ...
# 10053                     Ximex Optixitrol Eye Drop 5 ml
# 10054       Nature's Health Grape Seed Extract 60 Kapsul
# 10055  Eyesight Kitty Kawaii Mini Olivia Light Brown ...
# 10056       Nature's Health Grape Seed Extract 30 Kapsul
# 10057                             Sitro 150 mg 10 Tablet
#
#                                                komposisi  \
# 0                                                TEENMAX
# 1                                                MIXSAGA
# 2                                                MIXSAGA
# 3                                               PASOPATI
# 4                                           - ETORICOXIB
# ...                                                  ...
# 10053  - NEOMYCIN SULFATE. DEXAMETHASONE SODIUM PHOSP...
# 10054                  NATURES HEALTH GRAPE SEED EXTRACT
# 10055                    - KOMBINASI-VALSARTAN BLEND 32%
# 10056                  NATURES HEALTH GRAPE SEED EXTRACT
# 10057                                    - ROXITHROMYCIN
#
#                        price  \
# 0      Rp192.800 - Rp240.000
# 1        Rp25.000 - Rp33.700
# 2        Rp25.000 - Rp33.700
# 3        Rp52.300 - Rp84.800
# 4        Rp83.200 - Rp97.700
# ...                      ...
# 10053    Rp26.300 - Rp27.400
# 10054  Rp216.700 - Rp245.700
# 10055              Rp106.200
# 10056  Rp161.000 - Rp281.300
# 10057   Rp93.900 - Rp104.600
#
#                                             Aturan Pakai  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 10053                 teteskan pada mata yang terinfeksi
# 10054                                      Sesudah makan
# 10055  Bersihkan tangan sebelum menggunakan softlens....
# 10056                                                NaN
# 10057                                      Sebelum makan
#
#                                                    Dosis  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 10053  PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 10054                                      2 kapsul/hari
# 10055                                                NaN
# 10056                                  2 kapsul per hari
# 10057  PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
#
#                                            Indikasi Umum  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 10053  gangguan inflamasi ocular yang diindikasikan k...
# 10054  Membantu memelihara kesehatan, membantu menceg...
# 10055  Eyesight Kitty Kawaii Mini Olivia Light Brown ...
# 10056  Membantu mencegah timbulnya enzim yang merusak...
# 10057  Masalah pendinginan jangka pendek dan cepat da...
#
#                                       Kemasan  \
# 0                         Dus, Botol @ 350 ml
# 1                  Dus, Botol Plastik @ 10 ml
# 2                  Dus, Botol Plastik @ 10 ml
# 3                                         NaN
# 4      Dus, 3 Strip @ 10 Tablet Salut Selaput
# ...                                       ...
# 10053                            Botol @ 5 ml
# 10054                       Botol @ 60 Kapsul
# 10055             Box @ 2 Soft Contact Lense.
# 10056                       Botol @ 30 Kapsul
# 10057                      Tablet 150 mg x 30
#
#                                          Kontra Indikasi  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 10053  Keratitis herpes simplex epithelial (dendritis...
# 10054                                                NaN
# 10055                                                NaN
# 10056                                                NaN
# 10057                                      Hipersensitif
#
#                                                Perhatian   types  \
# 0                                                    NaN     NaN
# 1                                                    NaN     NaN
# 2                                                    NaN     NaN
# 3                                                    NaN  kapsul
# 4                                                    NaN  tablet
# ...                                                  ...     ...
# 10053  HARUS DENGAN RESEP DOKTER. Penggunaan jangka p...   tetes
# 10054  Simpan dalam tempat tertutup rapat, Hindari da...  kapsul
# 10055  Produk ini merupakan Softlens Minus yang dituj...  tablet
# 10056                                                NaN  kapsul
# 10057       HARUS DENGAN RESEP DOKTER. Insufisiensi hati  tablet
#
#                                         prepro_komposisi  \
# 0                                                teenmax
# 1                                                mixsaga
# 2                                                mixsaga
# 3                                               pasopati
# 4                                             etoricoxib
# ...                                                  ...
# 10053  neomycin sulfate dexamethasone sodium phosphat...
# 10054                  natures health grape seed extract
# 10055                      kombinasi-valsartan blend 32%
# 10056                  natures health grape seed extract
# 10057                                      roxithromycin
#
#                                       prepro_indications  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 10053  gangguan inflamasi ocular diindikasikan kortik...
# 10054  membantu memelihara kesehatan , membantu mence...
# 10055  eyesight kitty kawaii mini olivia light brown ...
# 10056  membantu mencegah timbulnya enzim merusak jari...
# 10057  masalah pendinginan jangka pendek cepat olah r...
#
#                                            cleaned_names  \
# 0                                                teenmax
# 1                                                mixsaga
# 2                                                mixsaga
# 3                                               pasopati
# 4                                             etoricoxib
# ...                                                  ...
# 10053                          ximex optixitrol eye drop
# 10054                  natures health grape seed extract
# 10055  eyesight kitty kawaii mini olivia light brown ...
# 10056                  natures health grape seed extract
# 10057                                              sitro
#
#                                                  summary  word_count  \
# 0                                              teenmax             1
# 1                                              mixsaga             1
# 2                                              mixsaga             1
# 3                                       pasopati kapsul            2
# 4                                     etoricoxib tablet            2
# ...                                                  ...         ...
# 10053  ximex optixitrol eye drop tetes neomycin sulfa...          79
# 10054  natures health grape seed extract kapsul memba...          81
# 10055  eyesight kitty kawaii mini olivia light brown ...          81
# 10056  natures health grape seed extract kapsul memba...          81
# 10057  sitro tablet roxithromycin masalah pendingi ja...         364
#
#        max_length
# 0              16
# 1              16
# 2              16
# 3              16
# 4              16
# ...           ...
# 10053         128
# 10054         128
# 10055         128
# 10056         128
# 10057         128
#
# [10058 rows x 19 columns]

# %%
import numpy as np

def filter_parts(value):
    if value == 'None':
        return np.nan
    split_values = value.lower().split(':')
    filtered_parts = [part for part in split_values if '|' in part]
    return '|'.join(filtered_parts) if filtered_parts else value.lower()

# Create a new column with filtered parts
sample['indikasi'] = sample['indikasi'].map(filter_parts)
sample['indikasi'] = sample['indikasi'].str.replace('"', '').str.replace('\n', '')

# %%
sample
# Out:
#         id nomor_registrasi                       nama   types  \
# 1621  3514  DKL1007810604A1                    hufadon  kaplet
# 4175  8759  DKL0804520010A1                    norizec  tablet
# 4356  9097  DKI0367501817C1                     diovan  tablet
# 2165  4681  DKL1203813646A1                 lentikular   tetes
# 287    926  DKL0804130337A1  comtusi (rasa strawberry)   sirup
# ...    ...              ...                        ...     ...
# 3324  6728  DKL0304421302B1                      oscal  kapsul
# 3090  6354  DKL0609215704A1                    rexavin  kaplet
# 1683  3612  DKL1733537682A1                     monell  tablet
# 2463  5356  DKL0434601629A1                     afucid    krim
# 2639  5674  GKL0208505538A1     cefadroxil monohydrate   sirup
#
#                      komposisi  \
# 1621               domperidone
# 4175               glimepiride
# 4356                 valsartan
# 2165                pirenoxine
# 287   oxomemazine| guaifenesin
# ...                        ...
# 3324                calcitriol
# 3090              griseofulvin
# 1683               domperidone
# 2463              fusidic acid
# 2639    cefadroxil monohydrate
#
#                                      prepro_indications  \
# 1621  terapi mual muntah disebabkan levodopa bromokr...
# 4175  diabetes melitus tipe 2 non - insulin - depend...
# 4356  hipertensi , gagal jantung , pasca infark miokard
# 2165                 membantu mengatasi kekeringan mata
# 287   untuk meringankan gejala batuk alergi , batuk ...
# ...                                                 ...
# 3324  osteoporosis pasca menopause  osteodistrofi re...
# 3090                                                NaN
# 1683  mual muntah akut , dispepsia gangguan pencerna...
# 2463  impetigo kontagiosum , folikulitis superfisial...
# 2639  mengatasi infeksi saluran pernafasan , saluran...
#
#                                                indikasi  \
# 1621            mual muntah|kanker|dispepsia fungsional
# 4175  diabetes melitus tipe 2|non-insulin-dependent ...
# 4356            hipertensi|gagal jantung|infark miokard
# 2165                                    kekeringan mata
# 287                         batuk alergi|batuk berdahak
# ...                                                 ...
# 3324  osteoporosis|osteodistrofi renal|gangguan ginj...
# 3090                                                NaN
# 1683  mual muntah akut|mual muntah anak akibat kemot...
# 2463  impetigo kontagiosum|folikulitis superfisial|f...
# 2639  infeksi saluran pernafasan|infeksi saluran kem...
#
#                                       filtered_indikasi
# 1621            mual muntah|kanker|dispepsia fungsional
# 4175  diabetes melitus tipe 2|non-insulin-dependent ...
# 4356            hipertensi|gagal jantung|infark miokard
# 2165                                    kekeringan mata
# 287                         batuk alergi|batuk berdahak
# ...                                                 ...
# 3324  osteoporosis|osteodistrofi renal|gangguan ginj...
# 3090                                                NaN
# 1683  mual muntah akut|mual muntah anak akibat kemot...
# 2463  impetigo kontagiosum|folikulitis superfisial|f...
# 2639  infeksi saluran pernafasan|infeksi saluran kem...
#
# [100 rows x 8 columns]

# %%
sample.rename(columns={'types': 'tipe'}, inplace=True)
sample.drop(['prepro_indications'], axis=1, inplace=True)
sample

# %%
sample
# Out:
#         id nomor_registrasi                       nama    tipe  \
# 1621  3514  DKL1007810604A1                    hufadon  kaplet
# 4175  8759  DKL0804520010A1                    norizec  tablet
# 4356  9097  DKI0367501817C1                     diovan  tablet
# 2165  4681  DKL1203813646A1                 lentikular   tetes
# 287    926  DKL0804130337A1  comtusi (rasa strawberry)   sirup
# ...    ...              ...                        ...     ...
# 3324  6728  DKL0304421302B1                      oscal  kapsul
# 3090  6354  DKL0609215704A1                    rexavin  kaplet
# 1683  3612  DKL1733537682A1                     monell  tablet
# 2463  5356  DKL0434601629A1                     afucid    krim
# 2639  5674  GKL0208505538A1     cefadroxil monohydrate   sirup
#
#                      komposisi  \
# 1621               domperidone
# 4175               glimepiride
# 4356                 valsartan
# 2165                pirenoxine
# 287   oxomemazine| guaifenesin
# ...                        ...
# 3324                calcitriol
# 3090              griseofulvin
# 1683               domperidone
# 2463              fusidic acid
# 2639    cefadroxil monohydrate
#
#                                                indikasi
# 1621            mual muntah|kanker|dispepsia fungsional
# 4175  diabetes melitus tipe 2|non-insulin-dependent ...
# 4356            hipertensi|gagal jantung|infark miokard
# 2165                                    kekeringan mata
# 287                         batuk alergi|batuk berdahak
# ...                                                 ...
# 3324  osteoporosis|osteodistrofi renal|gangguan ginj...
# 3090                                                NaN
# 1683  mual muntah akut|mual muntah anak akibat kemot...
# 2463  impetigo kontagiosum|folikulitis superfisial|f...
# 2639  infeksi saluran pernafasan|infeksi saluran kem...
#
# [100 rows x 6 columns]

# %% [markdown]
# # Insert to Neo4J

# %%
graph.refresh_schema()
print(graph.schema)
# Out:
# Node properties:
#
# Relationship properties:
#
# The relationships:

# %%
df = pd.read_csv('sample_skripsi.csv')
df.fillna('-',inplace= True)
df.head(15)
df.to_csv('sample_skripsi.csv', inplace = True)
# Out:
#       id nomor_registrasi                             nama    tipe  \
# 0   3514  DKL1007810604A1                          hufadon  kaplet
# 1   8759  DKL0804520010A1                          norizec  tablet
# 2   9097  DKI0367501817C1                           diovan  tablet
# 3   4681  DKL1203813646A1                       lentikular   tetes
# 4    926  DKL0804130337A1        comtusi (rasa strawberry)   sirup
# 5    552  DKL7804407610B1                          salbron  tablet
# 6   4170  DKL1208018337A1                              bdm   sirup
# 7   7873      TR132673741               jagak - bebas gula       -
# 8   1496  DTL2032209837A1           nipe expectorant adult   sirup
# 9   1022  DTL0504129337A1  obh combi batuk + flu rasa madu   sirup
# 10  4196  DKL1433531317A1                        destavell  tablet
# 11  5929  DKL9604004504B1                         citoprim  kaplet
# 12  9085  DKI1631600710B1                          coveram  tablet
# 13  6616  DKL8714802610A1                          zoralin  tablet
# 14  8978  DKL0411634010B1                           v-bloc  tablet
#
#                                             komposisi  \
# 0                                         domperidone
# 1                                         glimepiride
# 2                                           valsartan
# 3                                          pirenoxine
# 4                            oxomemazine| guaifenesin
# 5                                  salbutamol sulfate
# 6                                       betamethasone
# 7                                                   -
# 8                                         guaifenesin
# 9   succus liquiritiae| paracetamol| ammonium chlo...
# 10                                      desloratadine
# 11                                   sulfamethoxazole
# 12          perindopril arginine| amlodipine besilate
# 13                                       ketoconazole
# 14                                         carvedilol
#
#                                              indikasi
# 0             mual muntah|kanker|dispepsia fungsional
# 1   diabetes melitus tipe 2|non-insulin-dependent ...
# 2             hipertensi|gagal jantung|infark miokard
# 3                                     kekeringan mata
# 4                         batuk alergi|batuk berdahak
# 5            asma bronkial|bronkritis kronik|emfisema
# 6         alergi saluran pernapasan|alergi kulit|mata
# 7                                                   -
# 8                                                   -
# 9       batuk|demam|sakit kepala|hiding bersin-bersin
# 10  alergi rinitis nasal|rinitis intermiten persis...
# 11  infeksi sal cerna|infeksi sal nafas|infeksi ba...
# 12                 hipertensi|penyakit arteri koroner
# 13  kandidiasis mukokutan khronis|infeksi jamur si...
# 14                    hipertensi|gagal jantung kronik

# %%
df
# Out:
#       id nomor_registrasi                       nama    tipe  \
# 0   3514  DKL1007810604A1                    hufadon  kaplet
# 1   8759  DKL0804520010A1                    norizec  tablet
# 2   9097  DKI0367501817C1                     diovan  tablet
# 3   4681  DKL1203813646A1                 lentikular   tetes
# 4    926  DKL0804130337A1  comtusi (rasa strawberry)   sirup
# ..   ...              ...                        ...     ...
# 95  6728  DKL0304421302B1                      oscal  kapsul
# 96  6354  DKL0609215704A1                    rexavin  kaplet
# 97  3612  DKL1733537682A1                     monell  tablet
# 98  5356  DKL0434601629A1                     afucid    krim
# 99  5674  GKL0208505538A1     cefadroxil monohydrate   sirup
#
#                    komposisi  \
# 0                domperidone
# 1                glimepiride
# 2                  valsartan
# 3                 pirenoxine
# 4   oxomemazine| guaifenesin
# ..                       ...
# 95                calcitriol
# 96              griseofulvin
# 97               domperidone
# 98              fusidic acid
# 99    cefadroxil monohydrate
#
#                                              indikasi
# 0             mual muntah|kanker|dispepsia fungsional
# 1   diabetes melitus tipe 2|non-insulin-dependent ...
# 2             hipertensi|gagal jantung|infark miokard
# 3                                     kekeringan mata
# 4                         batuk alergi|batuk berdahak
# ..                                                ...
# 95  osteoporosis|osteodistrofi renal|gangguan ginj...
# 96                                                  -
# 97  mual muntah akut|mual muntah anak akibat kemot...
# 98  impetigo kontagiosum|folikulitis superfisial|f...
# 99  infeksi saluran pernafasan|infeksi saluran kem...
#
# [100 rows x 6 columns]

# %%
# insert_query = """
# LOAD CSV WITH HEADERS FROM 'https://raw.githubusercontent.com/projectwilsen/skripsi/main/sample_skripsi.csv' AS row 
# MERGE (obat:Obat {nama: row.nama, id: row.id, no_regis: row.nomor_registrasi}) 
# FOREACH (kom in CASE WHEN row.komposisi IS NOT NULL THEN split(row.komposisi, '|') ELSE [] END | 
#     MERGE (komposisi:Komposisi {nama:trim(kom)}) 
#     MERGE (obat)-[:MENGANDUNG]->(komposisi)) 
# FOREACH (ind in CASE WHEN row.indikasi IS NOT NULL THEN split(row.indikasi, '|') ELSE [] END | 
#     MERGE (indikasi:Indikasi {nama:trim(ind)}) 
#     MERGE (obat)-[:MENGOBATI]->(indikasi)) 
# FOREACH (t in CASE WHEN row.tipe IS NOT NULL THEN [row.tipe] ELSE [] END | 
#     MERGE (tipe:Tipe {nama:t}) 
#     MERGE (obat)-[:TIPE]->(tipe))
# """

# insert_query = """
# LOAD CSV WITH HEADERS FROM 'https://raw.githubusercontent.com/projectwilsen/skripsi/main/sample_skripsi.csv' AS row 
# MERGE (obat:Obat {nama: row.nama, id: row.id, no_regis: row.nomor_registrasi}) 
# WITH row, obat, 
#      CASE WHEN row.komposisi IS NOT NULL THEN split(row.komposisi, '|') ELSE [] END AS komposisiList,
#      size(CASE WHEN row.komposisi IS NOT NULL THEN split(row.komposisi, '|') ELSE [] END) AS komposisiCount,
#      CASE WHEN row.indikasi IS NOT NULL THEN split(row.indikasi, '|') ELSE [] END AS indikasiList,
#      CASE WHEN row.tipe IS NOT NULL THEN [row.tipe] ELSE [] END AS tipeList

# FOREACH (kom in komposisiList |
#     MERGE (komposisi:Komposisi {nama: trim(kom)})
#     MERGE (obat)-[r:MENGANDUNG]->(komposisi)
#     SET r.weight = 1.0 / komposisiCount
# )

# FOREACH (ind in indikasiList |
#     MERGE (indikasi:Indikasi {nama: trim(ind)})
#     MERGE (obat)-[:MENGOBATI]->(indikasi)
# )

# FOREACH (t in tipeList |
#     MERGE (tipe:Tipe {nama: t})
#     MERGE (obat)-[:TIPE]->(tipe)
# )

# """

insert_query = """
LOAD CSV WITH HEADERS FROM 'https://raw.githubusercontent.com/projectwilsen/skripsi/main/sample_skripsi.csv' AS row 
MERGE (obat:Obat {nama: row.nama, id: row.id, no_regis: row.nomor_registrasi, tipe: COALESCE(row.tipe, 'None')}) 
WITH row, obat, 
     CASE WHEN row.komposisi IS NOT NULL THEN split(row.komposisi, '|') ELSE [] END AS komposisiList,
     size(CASE WHEN row.komposisi IS NOT NULL THEN split(row.komposisi, '|') ELSE [] END) AS komposisiCount,
     CASE WHEN row.indikasi IS NOT NULL THEN split(row.indikasi, '|') ELSE [] END AS indikasiList

FOREACH (kom in komposisiList |
    MERGE (komposisi:Komposisi {nama: trim(kom)})
    MERGE (obat)-[r:MENGANDUNG]->(komposisi)
    SET r.weight = 1.0 / komposisiCount
)

FOREACH (ind in indikasiList |
    MERGE (indikasi:Indikasi {nama: trim(ind)})
    MERGE (obat)-[:MENGOBATI]->(indikasi)
)


"""

graph.query(insert_query)
# Out:
# []

# %%
graph.refresh_schema()
print(graph.schema)
# Out:
# Node properties:
# Obat {id: STRING, nama: STRING, no_regis: STRING, tipe: STRING}
# Komposisi {nama: STRING}
# Indikasi {nama: STRING}
# Relationship properties:
# MENGANDUNG {weight: FLOAT}
# The relationships:
# (:Obat)-[:MENGANDUNG]->(:Komposisi)
# (:Obat)-[:MENGOBATI]->(:Indikasi)

# %%
graph.query(""" MATCH (komposisi:Komposisi {nama: 'paracetamol'})<-[r:MENGANDUNG]-(obat:Obat)
RETURN obat.nama AS Medicine,obat.id, r.weight AS Weight
ORDER BY r.weight DESC""")
# Out:
# [{'Medicine': 'pacetik-500', 'obat.id': '2621', 'Weight': 1.0},
#  {'Medicine': 'bodrex demam', 'obat.id': '2243', 'Weight': 1.0},
#  {'Medicine': 'panadol', 'obat.id': '2086', 'Weight': 1.0},
#  {'Medicine': 'xepamol', 'obat.id': '3001', 'Weight': 1.0},
#  {'Medicine': 'turpas forte', 'obat.id': '2999', 'Weight': 1.0},
#  {'Medicine': 'spasmal', 'obat.id': '3657', 'Weight': 0.5},
#  {'Medicine': 'hustab', 'obat.id': '1405', 'Weight': 0.3333333333333333},
#  {'Medicine': 'flucadex pe flu & batuk berdahak',
#   'obat.id': '1337',
#   'Weight': 0.3333333333333333},
#  {'Medicine': 'flunax', 'obat.id': '1347', 'Weight': 0.3333333333333333},
#  {'Medicine': 'ternix plus', 'obat.id': '1652', 'Weight': 0.25},
#  {'Medicine': 'obh combi batuk + flu rasa madu',
#   'obat.id': '1022',
#   'Weight': 0.2}]

# %% [markdown]
# # Chat

# %%
model = ChatGroq(temperature=0, model_name="llama3-70b-8192", groq_api_key = groq_api)
chain = GraphCypherQAChain.from_llm(graph=graph, llm=model, verbose=True)

# %%
questions = ["Apa obat untuk batuk?"]

for q in questions:
    print("\n", q)
    try:
        result = chain.invoke(q)['result']
        print(result)
    except:
        pass
# Out:
#  Apa obat untuk batuk?
#
#
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (o:Obat)-[:MENGOBATI]->(i:Indikasi) WHERE i.nama = "Batuk" RETURN o.nama;
# Full Context:
# []
#
# > Finished chain.
# I don't know the answer.

# %% [markdown]
# # ER Fasttext

# %%
import fasttext

model = fasttext.load_model('cc.id.300.bin')

# %%
import fasttext
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

def load_fasttext_model(model_path):
    """
    Load a FastText model from a given file path.
    """
    return fasttext.load_model(model_path)

def get_sentence_vector(model, sentence):
    """
    Get a vector representation of a sentence by averaging the word vectors.
    """
    words = sentence.split()
    word_vectors = [model.get_word_vector(word) for word in words if word in model.words]
    if len(word_vectors) == 0:
        return np.zeros((model.get_dimension(),))
    return np.mean(word_vectors, axis=0)

def map_names_to_standardized_fasttext(model, standardized_names, names_to_map, threshold=0.5):
    """
    Maps names from `names_to_map` to `standardized_names` using FastText embeddings and cosine similarity.
    
    Parameters:
    - model: Loaded FastText model.
    - standardized_names (list of str): List of standardized names.
    - names_to_map (list of str): List of names that need to be mapped.
    - threshold (float): Minimum cosine similarity score to consider a match.
    
    Returns:
    - tuple: 
        1. dict: A dictionary where keys are standardized names, and values are lists of mapped names.
        2. list: A list of names from `names_to_map` that haven't been mapped.
    """
    # Compute vectors for standardized names
    standardized_vectors = np.array([get_sentence_vector(model, name) for name in standardized_names])
    
    # Initialize a dictionary to store results
    mapping_dict = {name: [] for name in standardized_names}
    unmapped_names = []
    
    # Iterate over each name to map
    for name in names_to_map:
        # Get vector for the name to be mapped
        name_vector = get_sentence_vector(model, name).reshape(1, -1)
        
        # Calculate cosine similarities
        similarities = cosine_similarity(name_vector, standardized_vectors).flatten()
        
        # Find the index of the standardized name with the highest similarity
        best_match_index = np.argmax(similarities)
        best_match_score = similarities[best_match_index]
        
        # If the similarity is above the threshold, map it to the best match
        if best_match_score >= threshold:
            standardized_name = standardized_names[best_match_index]
            mapping_dict[standardized_name].append(name)
        else:
            # Add to unmapped names if no match found
            unmapped_names.append(name)
    
    return mapping_dict, unmapped_names

# Example usage:
model_path = 'cc.id.300.bin'  # Replace with your actual model path
fasttext_model = load_fasttext_model(model_path)

standardized_names = ["Hypertension", "Diabetes", "Cardiovascular Disease"]
names_to_map = ["High blood pressure", "Type 2 diabetes", "Heart disease", "Asthma"]

mapped_dict, unmapped_diseases = map_names_to_standardized_fasttext(fasttext_model, standardized_names, names_to_map, threshold=0.3)
print("Mapped Names:", mapped_dict)
print("Unmapped Names:", unmapped_diseases)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import fasttext
#       2 import numpy as np
#       3 from sklearn.metrics.pairwise import cosine_similarity
#
# ModuleNotFoundError: No module named 'fasttext'
